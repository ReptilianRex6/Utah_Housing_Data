# %%
from google.colab import files

files = files.upload()
# Out:
#      <input type="file" id="files-ebdbe6b2-adf1-47c5-9bca-6ab5ceccb185" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ebdbe6b2-adf1-47c5-9bca-6ab5ceccb185">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
import pandas as pd

# %%
df = pd.read_csv(io.BytesIO(files['UTBP1FH.csv']))

# %%
df .head(

)
# Out:
#          DATE  UTBP1FH
# 0  1988-01-01    212.0
# 1  1988-02-01    361.0
# 2  1988-03-01    484.0
# 3  1988-04-01    575.0
# 4  1988-05-01    579.0

# %%
df .tail(

)
# Out:
#            DATE  UTBP1FH
# 427  2023-08-01   1582.0
# 428  2023-09-01   1211.0
# 429  2023-10-01   1258.0
# 430  2023-11-01   1279.0
# 431  2023-12-01   1107.0

# %%
t = df.loc[:, 'DATE']
v = df.loc[:, 'UTBP1FH']

# %%
from matplotlib import pyplot as plt

fig, ax = plt.subplots(figsize=(12,9))
ax.plot(t,v)
